# %%
from utils import get_html, get_html_divs_with_class, get_ul_from_div, get_li_from_ul, get_urls_from_li
import requests

# %%
url = 'https://www.cs.tsinghua.edu.cn/index/xsbg.htm'

# %%
res = requests.get(url)
res.encoding
# Out:
# 'ISO-8859-1'

# %%
html = get_html(url)
html
# Out:
# b'\xef\xbb\xbf<!DOCTYPE html>\r\n<html>\r\n\t<head>\r\n\t\t<meta charset="utf-8">\r\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n\t\t<meta name="description" content="">\r\n\t\t\r\n\t\t<meta name="format-detection" content="telephone=no" />\r\n\t\t<meta name="format-detection" content="address=no">\r\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\r\n\t\t<meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=1.0,user-scalable=0">\r\n\t\t<meta name="renderer" content="webkit">\r\n\t\t<title>\xe5\xad\xa6\xe6\x9c\xaf\xe6\x8a\xa5\xe5\x91\x8a-\xe6\xb8\x85\xe5\x8d\x8e\xe5\xa4\xa7\xe5\xad\xa6\xe8\xae\xa1\xe7\xae\x97\xe6\x9c\xba\xe7\xa7\x91\xe5\xad\xa6\xe4\xb8\x8e\xe6\x8a\x80\xe6\x9c\xaf\xe7\xb3\xbb</title><META Name="keywords" Content="\xe6\xb8\x85\xe5\x8d\x8e\xe5\xa4\xa7\xe5\xad\xa6\xe8\xae\xa1\xe7\xae\x97\xe6\x9c\xba\xe7\xa7\x91\xe5\xad\xa6\xe4\xb8\x8e\xe6\x8a\x80\xe6\x9c\xaf\xe7\xb3\xbb" />\r\n\r\n\t\t<link rel="stylesheet" 
# ...

# %%
div = get_html_divs_with_class(html, class_name="list03")
div
# Out:
# <div class="list03">
# <script language="javascript" src="/system/resource/js/centerCutImg.js"></script><script language="javascript" src="/system/resource/js/ajax.js"></script><div>
# <ul>
# <li>
# <a href="../info/1089/5168.htm" title="清华计算机系诚邀您参加第三届全球计算机学科发展论坛">
# <div class="time">
# <div class="day">24</div>
# <div class="month">十月</div>
# </div>
# <div class="text">
# <h5>清华计算机系诚邀您参加第三届全球计算机学科发展论坛</h5>
# <p>“第三届全球计算机学科发展论坛”将于2022年10月28日晚上20点至23点在清华大学召开。本次论坛主题为“新时代下计算机学科的挑战与机遇”，论坛由交叉信息研究院院长、图灵奖获得者姚期智先生和计算机系主任尹霞教授主持，伊利诺伊大学、剑桥大学、韩国科学技术院的计算机系主任、香港科技大学的教务长分别进行特邀报告，最后姚期智先生和各位特邀嘉宾一起进行题为“新时代计算机学科...</p>
# </div>
# </a>
# </li>
# <li>
# <a href="../info/1089/4903.htm" title="首届量子软件论坛即将举办">
# <div class="time">
# <div class="day">18</div>
# <div class="month">四月</div>
# </div>
# <div class="text">
# <h5>首届量子软件论坛即将举办</h5>
# ...

# %%
ul = get_ul_from_div(div)
li = get_li_from_ul(ul)
urls = get_urls_from_li(li)
urls, len(urls)
# Out:
# (['../info/1089/5168.htm',
#   '../info/1089/4903.htm',
#   '../info/1089/4816.htm',
#   '../info/1089/4473.htm',
#   '../info/1089/4474.htm',
#   '../info/1089/3471.htm',
#   '../info/1089/3469.htm',
#   '../info/1089/3472.htm',
#   '../info/1089/3468.htm',
#   '../info/1089/3467.htm'],
#  10)
